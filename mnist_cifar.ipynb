# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import argparse

parser = argparse.ArgumentParser(description='Process some integers.')
parser.add_argument('--num_class', type=int,
                    help='')
parser.add_argument('--flip_ratio_list', nargs='+',type=float,
                    help='')
parser.add_argument('--class_ratio', type=float,
                    help='')

args = parser.parse_args("--num_class 2 --flip_ratio_list 0.3 0.7 --class_ratio 0.5".split())

# %%
args.flip_ratio_list
# Out:
# [0.3, 0.7]

# %%
from mnist_cifar10 import MNIST_CIFAR10

dataset = MNIST_CIFAR10(args)
# Out:
# Preparing MNIST CIFAR10
# DONE

# %%
print(dataset.train_img.shape)
print(dataset.train_labels.shape)
print(dataset.train_spurious_labels.shape)

print(dataset.test_img.shape)
print(dataset.test_labels.shape)
print(dataset.test_spurious_labels.shape)
# Out:
# torch.Size([10000, 64, 32, 3])
# torch.Size([10000])
# torch.Size([10000])
# torch.Size([1960, 64, 32, 3])
# torch.Size([1960])
# torch.Size([1960])

# %%
from matplotlib import pyplot as plt
idx = 10

plt.imshow(dataset.train_img[idx])
print(dataset.train_labels[idx].item(), dataset.train_spurious_labels[idx].item())
# Out:
# 1 1

# %%
idx = dataset.flipped_arr.index(True)

plt.imshow(dataset.test_img[0])
print(dataset.test_labels[idx].item(), dataset.test_spurious_labels[idx].item())
# Out:
# 1 0
